# %%
import numpy as np

from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize

from stardist import random_label_cmap
from stardist.matching import matching_dataset
from stardist.models import Config2D, StarDist2D

from sklearn.model_selection import KFold
import pandas as pd
import gc
import tensorflow as tf

np.random.seed(42)
lbl_cmap = random_label_cmap()
# Out:
# 2024-07-12 20:09:15.340006: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
X = sorted(glob('datasets/not_split/Aggregates/images/*.tif'))
Y = sorted(glob('datasets/not_split/Aggregates/masks/*.tif'))

# %%
assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))

X = list(map(imread,X))
Y = list(map(imread,Y))

# %%
X = [normalize(x,1,99.9,axis=(0,1)) for x in tqdm(X)]
# Out:
# 100%|██████████| 1284/1284 [00:00<00:00, 1326.42it/s]

# %%
model_name = 'aggregates_pretrained'
model_dir = 'final_models'

results_file = 'results/results.csv'

# %%
conf = Config2D (
    n_rays       = 32,
    grid         = (2,2),
    n_channel_in = 1,
    train_dist_loss = 'iou',
    train_epochs = 350
)

vars(conf)
# Out:
# {'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 1,
#  'n_channel_out': 33,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'n_rays': 32,
#  'grid': (2, 2),
#  'backbone': 'unet',
#  'n_classes': None,
#  'unet_n_depth': 3,
#  'unet_kernel_size': (3, 3),
#  'unet_n_filter_base': 32,
#  'unet_n_conv_per_depth': 2,
#  'unet_pool': (2, 2),
#  'unet_activation': 'relu',
#  'unet_last_activation': 'relu',
#  'unet_batch_norm': False,
#  'unet_dropout': 0.0,
#  'unet_prefix': '',
#  'net_conv_after_unet': 128,
#  'net_input_shape': (None, None, 1),
#  'net_mask_shape': (None, None, 1),
#  'train_shape_completion': False,
#  'train_completion_crop': 32,
#  'train_patch_size': (256, 256),
#  'train_background_reg': 0.0001,
#  'train_foreground_only': 0.9,
#  'train_sample_cache': True,
#  'train_dist_loss': 'iou',
#  'train_loss_weights': (1, 0.2),
#  'train_class_weights': (1, 1),
#  'train_epochs': 350,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0003,
#  'train_batch_size': 4,
#  'train_n_val_patches': None,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 40, 'min_delta': 0},
#  'use_gpu': False}

# %%
def random_fliprot(img, mask): 
    assert img.ndim >= mask.ndim
    axes = tuple(range(mask.ndim))
    perm = tuple(np.random.permutation(axes))
    img = img.transpose(perm + tuple(range(mask.ndim, img.ndim))) 
    mask = mask.transpose(perm) 
    for ax in axes: 
        if np.random.rand() > 0.5:
            img = np.flip(img, axis=ax)
            mask = np.flip(mask, axis=ax)
    return img, mask 

def random_intensity_change(img):
    img = img*np.random.uniform(0.6,2) + np.random.uniform(-0.2,0.2)
    return img


def augmenter(x, y):
    """Augmentation of a single input/label image pair.
    x is an input image
    y is the corresponding ground-truth label image
    """
    x, y = random_fliprot(x, y)
    # x = random_intensity_change(x)
    # add some gaussian noise
    sig = 0.02*np.random.uniform(0,1)
    x = x + sig*np.random.normal(0,1,x.shape)
    return x, y

# %%
def cross_validate_stardist(images, masks, n_splits=5, start_from_fold=0):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(images)):

        if fold < start_from_fold:
            continue  # Skip to the desired starting fold

        print(f"Starting fold {fold + 1}/{n_splits}...")
        
        # Splitting the dataset
        train_images, test_images = [images[i] for i in train_idx], [images[i] for i in test_idx]
        train_masks, test_masks = [masks[i] for i in train_idx], [masks[i] for i in test_idx]

        # model = StarDist2D.from_pretrained('2D_versatile_fluo')

        # Initialize Stardist model
        model = StarDist2D(conf, name=model_name+str(fold), basedir=model_dir)

        model.train(train_images, train_masks, validation_data=(test_images,test_masks), augmenter=augmenter, seed=42)
        model.optimize_thresholds(test_images, test_masks)
        
        # Evaluation
        Y_pred = [model.predict_instances(x, show_tile_progress=False)[0] for x in test_images]

        stat = matching_dataset(test_masks, Y_pred, thresh=0.1, show_progress=False)

        data = {
            'model': [model_name+str(fold)],
            'tp': [stat.tp],
            'fp': [stat.fp],
            'fn': [stat.fn],
            'precision': [stat.precision],
            'recall': [stat.recall],
            'accuracy': [stat.accuracy]
        }

        df = pd.DataFrame(data)

        df1 = pd.read_csv(results_file)

        merged_df = pd.concat([df1, df], ignore_index=True)
        merged_df = merged_df.sort_values(by='model', ascending=True)

        merged_df.to_csv(results_file, index=False)
        
        print(f"Fold {fold + 1} completed.")

# %%
cross_validate_stardist(X, Y, n_splits=5, start_from_fold=4)
# Out:
# Starting fold 5/5...
# base_model.py (149): output path for model already exists, files may be overwritten: /home/deivis/VU/SRP/code/stardist/final_v1/final_models/aggregates_pretrained4
# 2024-07-12 20:09:25.878794: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-07-12 20:09:25.881756: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-07-12 20:09:26.679394: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.679448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4070 Ti computeCapability: 8.9
# coreClock: 2.61GHz coreCount: 60 deviceMemorySize: 11.99GiB deviceMemoryBandwidth: 469.43GiB/s
# 2024-07-12 20:09:26.679486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-07-12 20:09:26.681652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-07-12 20:09:26.681687: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2024-07-12 20:09:26.682413: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-07-12 20:09:26.682664: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-07-12 20:09:26.684421: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-07-12 20:09:26.684713: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2024-07-12 20:09:26.684798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2024-07-12 20:09:26.684921: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.684959: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.684970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-07-12 20:09:26.685712: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-12 20:09:26.688805: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-07-12 20:09:26.689007: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.689023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 4070 Ti computeCapability: 8.9
# coreClock: 2.61GHz coreCount: 60 deviceMemorySize: 11.99GiB deviceMemoryBandwidth: 469.43GiB/s
# 2024-07-12 20:09:26.689039: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-07-12 20:09:26.689050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-07-12 20:09:26.689057: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2024-07-12 20:09:26.689064: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-07-12 20:09:26.689071: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-07-12 20:09:26.689078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-07-12 20:09:26.689085: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2024-07-12 20:09:26.689092: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2024-07-12 20:09:26.689128: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.689153: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:26.689158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-07-12 20:09:26.689192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2024-07-12 20:09:27.394278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-07-12 20:09:27.394307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-07-12 20:09:27.394320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-07-12 20:09:27.394689: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:27.394701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1489] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-07-12 20:09:27.394744: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:27.394836: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-12 20:09:27.394899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10240 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9)
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.417819, nms_thresh=0.5.
# 2024-07-12 20:09:28.838415: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-07-12 20:09:28.838793: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 4192045000 Hz
# Epoch 1/350
# WARNING:tensorflow:AutoGraph could not transform <function _gcd_import at 0x7f5f052a2430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <function _gcd_import at 0x7f5f052a2430>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function _gcd_import at 0x7f5f052a2430> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Unable to locate the source code of <function _gcd_import at 0x7f5f052a2430>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2024-07-12 20:09:30.056308: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2024-07-12 20:09:32.182662: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2024-07-12 20:09:32.246190: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-07-12 20:09:34.135257: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2024-07-12 20:09:34.743674: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
#   5/100 [>.............................] - ETA: 4s - loss: 0.8852 - prob_loss: 0.6853 - dist_loss: 0.9995 - prob_kld: 0.6850 - dist_relevant_mae: 3.3674 - dist_relevant_mse: 15.7869 - dist_dist_iou_metric: 1.7550e-04   WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0203s vs `on_train_batch_end` time: 0.0226s). Check your callbacks.
# 100/100 [==============================] - 92s 33ms/step - loss: 0.3944 - prob_loss: 0.2091 - dist_loss: 0.9269 - prob_kld: 0.2007 - dist_relevant_mae: 4.1387 - dist_relevant_mse: 31.2399 - dist_dist_iou_metric: 0.1238 - val_loss: 0.1430 - val_prob_loss: 0.0115 - val_dist_loss: 0.6575 - val_prob_kld: 0.0105 - val_dist_relevant_mae: 2.7350 - val_dist_relevant_mse: 12.4098 - val_dist_dist_iou_metric: 0.3433
# Epoch 2/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1401 - prob_loss: 0.0108 - dist_loss: 0.6464 - prob_kld: 0.0099 - dist_relevant_mae: 2.4879 - dist_relevant_mse: 9.7182 - dist_dist_iou_metric: 0.3488 - val_loss: 0.1357 - val_prob_loss: 0.0103 - val_dist_loss: 0.6274 - val_prob_kld: 0.0093 - val_dist_relevant_mae: 2.7067 - val_dist_relevant_mse: 11.1631 - val_dist_dist_iou_metric: 0.3729
# Epoch 3/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1354 - prob_loss: 0.0113 - dist_loss: 0.6205 - prob_kld: 0.0103 - dist_relevant_mae: 2.3946 - dist_relevant_mse: 8.7227 - dist_dist_iou_metric: 0.3798 - val_loss: 0.1344 - val_prob_loss: 0.0092 - val_dist_loss: 0.6263 - val_prob_kld: 0.0082 - val_dist_relevant_mae: 2.1592 - val_dist_relevant_mse: 8.7269 - val_dist_dist_iou_metric: 0.3739
# Epoch 4/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1298 - prob_loss: 0.0098 - dist_loss: 0.5997 - prob_kld: 0.0089 - dist_relevant_mae: 2.1552 - dist_relevant_mse: 7.0300 - dist_dist_iou_metric: 0.4006 - val_loss: 0.1198 - val_prob_loss: 0.0090 - val_dist_loss: 0.5539 - val_prob_kld: 0.0080 - val_dist_relevant_mae: 1.9279 - val_dist_relevant_mse: 7.1547 - val_dist_dist_iou_metric: 0.4463
# Epoch 5/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1098 - prob_loss: 0.0089 - dist_loss: 0.5045 - prob_kld: 0.0079 - dist_relevant_mae: 1.6937 - dist_relevant_mse: 4.7467 - dist_dist_iou_metric: 0.4959 - val_loss: 0.1003 - val_prob_loss: 0.0076 - val_dist_loss: 0.4634 - val_prob_kld: 0.0066 - val_dist_relevant_mae: 1.7170 - val_dist_relevant_mse: 5.8637 - val_dist_dist_iou_metric: 0.5371
# Epoch 6/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1009 - prob_loss: 0.0075 - dist_loss: 0.4671 - prob_kld: 0.0066 - dist_relevant_mae: 1.4769 - dist_relevant_mse: 3.7954 - dist_dist_iou_metric: 0.5335 - val_loss: 0.0874 - val_prob_loss: 0.0041 - val_dist_loss: 0.4166 - val_prob_kld: 0.0031 - val_dist_relevant_mae: 1.4645 - val_dist_relevant_mse: 4.3934 - val_dist_dist_iou_metric: 0.5838
# Epoch 7/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0886 - prob_loss: 0.0041 - dist_loss: 0.4221 - prob_kld: 0.0032 - dist_relevant_mae: 1.3416 - dist_relevant_mse: 3.3807 - dist_dist_iou_metric: 0.5671 - val_loss: 0.0832 - val_prob_loss: 0.0034 - val_dist_loss: 0.3987 - val_prob_kld: 0.0025 - val_dist_relevant_mae: 1.3073 - val_dist_relevant_mse: 4.2099 - val_dist_dist_iou_metric: 0.6016
# Epoch 8/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0808 - prob_loss: 0.0036 - dist_loss: 0.3862 - prob_kld: 0.0026 - dist_relevant_mae: 1.1771 - dist_relevant_mse: 2.4504 - dist_dist_iou_metric: 0.6141 - val_loss: 0.0820 - val_prob_loss: 0.0034 - val_dist_loss: 0.3926 - val_prob_kld: 0.0024 - val_dist_relevant_mae: 1.2797 - val_dist_relevant_mse: 4.0804 - val_dist_dist_iou_metric: 0.6077
# Epoch 9/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0823 - prob_loss: 0.0030 - dist_loss: 0.3967 - prob_kld: 0.0020 - dist_relevant_mae: 1.1556 - dist_relevant_mse: 2.4253 - dist_dist_iou_metric: 0.6036 - val_loss: 0.0873 - val_prob_loss: 0.0040 - val_dist_loss: 0.4163 - val_prob_kld: 0.0029 - val_dist_relevant_mae: 1.4461 - val_dist_relevant_mse: 4.1721 - val_dist_dist_iou_metric: 0.5841
# Epoch 10/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0810 - prob_loss: 0.0045 - dist_loss: 0.3825 - prob_kld: 0.0034 - dist_relevant_mae: 1.1737 - dist_relevant_mse: 2.6088 - dist_dist_iou_metric: 0.6155 - val_loss: 0.0877 - val_prob_loss: 0.0030 - val_dist_loss: 0.4234 - val_prob_kld: 0.0020 - val_dist_relevant_mae: 1.3229 - val_dist_relevant_mse: 4.3679 - val_dist_dist_iou_metric: 0.5768
# Epoch 11/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0779 - prob_loss: 0.0023 - dist_loss: 0.3777 - prob_kld: 0.0015 - dist_relevant_mae: 1.0836 - dist_relevant_mse: 2.1492 - dist_dist_iou_metric: 0.6225 - val_loss: 0.0796 - val_prob_loss: 0.0029 - val_dist_loss: 0.3838 - val_prob_kld: 0.0019 - val_dist_relevant_mae: 1.3008 - val_dist_relevant_mse: 3.8714 - val_dist_dist_iou_metric: 0.6166
# Epoch 12/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0782 - prob_loss: 0.0028 - dist_loss: 0.3770 - prob_kld: 0.0018 - dist_relevant_mae: 1.1107 - dist_relevant_mse: 2.4457 - dist_dist_iou_metric: 0.6233 - val_loss: 0.0760 - val_prob_loss: 0.0029 - val_dist_loss: 0.3659 - val_prob_kld: 0.0019 - val_dist_relevant_mae: 1.1912 - val_dist_relevant_mse: 3.5185 - val_dist_dist_iou_metric: 0.6343
# Epoch 13/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0752 - prob_loss: 0.0025 - dist_loss: 0.3638 - prob_kld: 0.0015 - dist_relevant_mae: 1.0661 - dist_relevant_mse: 2.2242 - dist_dist_iou_metric: 0.6351 - val_loss: 0.0783 - val_prob_loss: 0.0026 - val_dist_loss: 0.3783 - val_prob_kld: 0.0016 - val_dist_relevant_mae: 1.2194 - val_dist_relevant_mse: 3.8375 - val_dist_dist_iou_metric: 0.6219
# Epoch 14/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0770 - prob_loss: 0.0027 - dist_loss: 0.3713 - prob_kld: 0.0017 - dist_relevant_mae: 1.0781 - dist_relevant_mse: 2.2591 - dist_dist_iou_metric: 0.6289 - val_loss: 0.0751 - val_prob_loss: 0.0028 - val_dist_loss: 0.3619 - val_prob_kld: 0.0017 - val_dist_relevant_mae: 1.2095 - val_dist_relevant_mse: 3.3791 - val_dist_dist_iou_metric: 0.6384
# Epoch 15/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0736 - prob_loss: 0.0021 - dist_loss: 0.3576 - prob_kld: 0.0012 - dist_relevant_mae: 1.0398 - dist_relevant_mse: 2.0549 - dist_dist_iou_metric: 0.6426 - val_loss: 0.0768 - val_prob_loss: 0.0026 - val_dist_loss: 0.3712 - val_prob_kld: 0.0016 - val_dist_relevant_mae: 1.2711 - val_dist_relevant_mse: 3.4872 - val_dist_dist_iou_metric: 0.6290
# Epoch 16/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0758 - prob_loss: 0.0025 - dist_loss: 0.3666 - prob_kld: 0.0015 - dist_relevant_mae: 1.1138 - dist_relevant_mse: 2.5591 - dist_dist_iou_metric: 0.6309 - val_loss: 0.0735 - val_prob_loss: 0.0026 - val_dist_loss: 0.3545 - val_prob_kld: 0.0016 - val_dist_relevant_mae: 1.1819 - val_dist_relevant_mse: 3.3650 - val_dist_dist_iou_metric: 0.6457
# Epoch 17/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0717 - prob_loss: 0.0025 - dist_loss: 0.3464 - prob_kld: 0.0015 - dist_relevant_mae: 0.9669 - dist_relevant_mse: 1.9310 - dist_dist_iou_metric: 0.6538 - val_loss: 0.0718 - val_prob_loss: 0.0024 - val_dist_loss: 0.3468 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1337 - val_dist_relevant_mse: 3.2726 - val_dist_dist_iou_metric: 0.6534
# Epoch 18/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0712 - prob_loss: 0.0022 - dist_loss: 0.3452 - prob_kld: 0.0013 - dist_relevant_mae: 1.0339 - dist_relevant_mse: 2.1188 - dist_dist_iou_metric: 0.6546 - val_loss: 0.0747 - val_prob_loss: 0.0025 - val_dist_loss: 0.3610 - val_prob_kld: 0.0015 - val_dist_relevant_mae: 1.2149 - val_dist_relevant_mse: 3.2669 - val_dist_dist_iou_metric: 0.6392
# Epoch 19/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0717 - prob_loss: 0.0019 - dist_loss: 0.3492 - prob_kld: 0.0010 - dist_relevant_mae: 1.0176 - dist_relevant_mse: 1.9820 - dist_dist_iou_metric: 0.6510 - val_loss: 0.0727 - val_prob_loss: 0.0025 - val_dist_loss: 0.3515 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1472 - val_dist_relevant_mse: 3.2169 - val_dist_dist_iou_metric: 0.6488
# Epoch 20/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0716 - prob_loss: 0.0022 - dist_loss: 0.3471 - prob_kld: 0.0012 - dist_relevant_mae: 1.0575 - dist_relevant_mse: 2.2613 - dist_dist_iou_metric: 0.6198 - val_loss: 0.0706 - val_prob_loss: 0.0024 - val_dist_loss: 0.3407 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1280 - val_dist_relevant_mse: 3.0570 - val_dist_dist_iou_metric: 0.6595
# Epoch 21/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0705 - prob_loss: 0.0022 - dist_loss: 0.3417 - prob_kld: 0.0012 - dist_relevant_mae: 0.9885 - dist_relevant_mse: 1.9980 - dist_dist_iou_metric: 0.6585 - val_loss: 0.0720 - val_prob_loss: 0.0025 - val_dist_loss: 0.3476 - val_prob_kld: 0.0015 - val_dist_relevant_mae: 1.1325 - val_dist_relevant_mse: 3.2787 - val_dist_dist_iou_metric: 0.6526
# Epoch 22/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0733 - prob_loss: 0.0025 - dist_loss: 0.3543 - prob_kld: 0.0015 - dist_relevant_mae: 1.0685 - dist_relevant_mse: 2.3579 - dist_dist_iou_metric: 0.6460 - val_loss: 0.0715 - val_prob_loss: 0.0024 - val_dist_loss: 0.3451 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1482 - val_dist_relevant_mse: 3.0948 - val_dist_dist_iou_metric: 0.6551
# Epoch 23/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0686 - prob_loss: 0.0021 - dist_loss: 0.3322 - prob_kld: 0.0011 - dist_relevant_mae: 0.9448 - dist_relevant_mse: 1.7901 - dist_dist_iou_metric: 0.6680 - val_loss: 0.0721 - val_prob_loss: 0.0024 - val_dist_loss: 0.3480 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1249 - val_dist_relevant_mse: 3.2562 - val_dist_dist_iou_metric: 0.6523
# Epoch 24/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0713 - prob_loss: 0.0021 - dist_loss: 0.3463 - prob_kld: 0.0011 - dist_relevant_mae: 0.9921 - dist_relevant_mse: 1.9430 - dist_dist_iou_metric: 0.6540 - val_loss: 0.0726 - val_prob_loss: 0.0025 - val_dist_loss: 0.3507 - val_prob_kld: 0.0015 - val_dist_relevant_mae: 1.1597 - val_dist_relevant_mse: 3.1601 - val_dist_dist_iou_metric: 0.6496
# Epoch 25/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0702 - prob_loss: 0.0021 - dist_loss: 0.3407 - prob_kld: 0.0012 - dist_relevant_mae: 1.0094 - dist_relevant_mse: 1.9828 - dist_dist_iou_metric: 0.6595 - val_loss: 0.0761 - val_prob_loss: 0.0023 - val_dist_loss: 0.3689 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.1536 - val_dist_relevant_mse: 3.3885 - val_dist_dist_iou_metric: 0.6314
# Epoch 26/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0681 - prob_loss: 0.0017 - dist_loss: 0.3318 - prob_kld: 8.9932e-04 - dist_relevant_mae: 0.9070 - dist_relevant_mse: 1.5389 - dist_dist_iou_metric: 0.6685 - val_loss: 0.0695 - val_prob_loss: 0.0025 - val_dist_loss: 0.3350 - val_prob_kld: 0.0015 - val_dist_relevant_mae: 1.0934 - val_dist_relevant_mse: 3.0576 - val_dist_dist_iou_metric: 0.6652
# Epoch 27/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0702 - prob_loss: 0.0024 - dist_loss: 0.3386 - prob_kld: 0.0015 - dist_relevant_mae: 0.9485 - dist_relevant_mse: 1.8228 - dist_dist_iou_metric: 0.6616 - val_loss: 0.0768 - val_prob_loss: 0.0023 - val_dist_loss: 0.3723 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.1634 - val_dist_relevant_mse: 3.5776 - val_dist_dist_iou_metric: 0.6279
# Epoch 28/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0693 - prob_loss: 0.0018 - dist_loss: 0.3373 - prob_kld: 9.7087e-04 - dist_relevant_mae: 0.9668 - dist_relevant_mse: 1.8266 - dist_dist_iou_metric: 0.6556 - val_loss: 0.0697 - val_prob_loss: 0.0024 - val_dist_loss: 0.3365 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.0965 - val_dist_relevant_mse: 3.1217 - val_dist_dist_iou_metric: 0.6638
# Epoch 29/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0705 - prob_loss: 0.0020 - dist_loss: 0.3423 - prob_kld: 0.0011 - dist_relevant_mae: 1.0177 - dist_relevant_mse: 2.2406 - dist_dist_iou_metric: 0.6579 - val_loss: 0.0699 - val_prob_loss: 0.0023 - val_dist_loss: 0.3380 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0958 - val_dist_relevant_mse: 3.0922 - val_dist_dist_iou_metric: 0.6622
# Epoch 30/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0670 - prob_loss: 0.0020 - dist_loss: 0.3247 - prob_kld: 0.0011 - dist_relevant_mae: 0.9833 - dist_relevant_mse: 1.9609 - dist_dist_iou_metric: 0.6755 - val_loss: 0.0696 - val_prob_loss: 0.0023 - val_dist_loss: 0.3364 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0788 - val_dist_relevant_mse: 2.9861 - val_dist_dist_iou_metric: 0.6639
# Epoch 31/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0691 - prob_loss: 0.0021 - dist_loss: 0.3345 - prob_kld: 0.0011 - dist_relevant_mae: 0.9893 - dist_relevant_mse: 1.9003 - dist_dist_iou_metric: 0.6657 - val_loss: 0.0801 - val_prob_loss: 0.0023 - val_dist_loss: 0.3891 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.2032 - val_dist_relevant_mse: 3.6860 - val_dist_dist_iou_metric: 0.6111
# Epoch 32/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0696 - prob_loss: 0.0022 - dist_loss: 0.3369 - prob_kld: 0.0011 - dist_relevant_mae: 1.0219 - dist_relevant_mse: 2.1456 - dist_dist_iou_metric: 0.6634 - val_loss: 0.0728 - val_prob_loss: 0.0024 - val_dist_loss: 0.3520 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.1158 - val_dist_relevant_mse: 3.1284 - val_dist_dist_iou_metric: 0.6483
# Epoch 33/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0720 - prob_loss: 0.0024 - dist_loss: 0.3481 - prob_kld: 0.0014 - dist_relevant_mae: 1.0075 - dist_relevant_mse: 2.1968 - dist_dist_iou_metric: 0.6522 - val_loss: 0.0700 - val_prob_loss: 0.0024 - val_dist_loss: 0.3380 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.0851 - val_dist_relevant_mse: 3.0784 - val_dist_dist_iou_metric: 0.6623
# Epoch 34/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0699 - prob_loss: 0.0021 - dist_loss: 0.3391 - prob_kld: 0.0011 - dist_relevant_mae: 0.9720 - dist_relevant_mse: 1.8760 - dist_dist_iou_metric: 0.6612 - val_loss: 0.0846 - val_prob_loss: 0.0023 - val_dist_loss: 0.4115 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.2570 - val_dist_relevant_mse: 3.8982 - val_dist_dist_iou_metric: 0.5887
# Epoch 35/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0738 - prob_loss: 0.0028 - dist_loss: 0.3554 - prob_kld: 0.0017 - dist_relevant_mae: 1.0204 - dist_relevant_mse: 2.1565 - dist_dist_iou_metric: 0.6448 - val_loss: 0.0792 - val_prob_loss: 0.0023 - val_dist_loss: 0.3847 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.1922 - val_dist_relevant_mse: 3.4653 - val_dist_dist_iou_metric: 0.6156
# Epoch 36/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0695 - prob_loss: 0.0021 - dist_loss: 0.3369 - prob_kld: 0.0010 - dist_relevant_mae: 0.9790 - dist_relevant_mse: 1.9005 - dist_dist_iou_metric: 0.6621 - val_loss: 0.0706 - val_prob_loss: 0.0023 - val_dist_loss: 0.3418 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.1470 - val_dist_relevant_mse: 2.9519 - val_dist_dist_iou_metric: 0.6584
# Epoch 37/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0669 - prob_loss: 0.0019 - dist_loss: 0.3254 - prob_kld: 9.4800e-04 - dist_relevant_mae: 0.9562 - dist_relevant_mse: 1.8004 - dist_dist_iou_metric: 0.6749 - val_loss: 0.0706 - val_prob_loss: 0.0024 - val_dist_loss: 0.3411 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1432 - val_dist_relevant_mse: 3.0419 - val_dist_dist_iou_metric: 0.6592
# Epoch 38/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0670 - prob_loss: 0.0020 - dist_loss: 0.3246 - prob_kld: 0.0011 - dist_relevant_mae: 0.9397 - dist_relevant_mse: 1.6916 - dist_dist_iou_metric: 0.6756 - val_loss: 0.0680 - val_prob_loss: 0.0023 - val_dist_loss: 0.3285 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0710 - val_dist_relevant_mse: 2.8787 - val_dist_dist_iou_metric: 0.6718
# Epoch 39/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0676 - prob_loss: 0.0021 - dist_loss: 0.3276 - prob_kld: 0.0011 - dist_relevant_mae: 0.9978 - dist_relevant_mse: 2.0113 - dist_dist_iou_metric: 0.6726 - val_loss: 0.0673 - val_prob_loss: 0.0022 - val_dist_loss: 0.3254 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0624 - val_dist_relevant_mse: 2.9047 - val_dist_dist_iou_metric: 0.6748
# Epoch 40/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0650 - prob_loss: 0.0018 - dist_loss: 0.3156 - prob_kld: 9.1335e-04 - dist_relevant_mae: 0.9167 - dist_relevant_mse: 1.7271 - dist_dist_iou_metric: 0.6846 - val_loss: 0.0682 - val_prob_loss: 0.0022 - val_dist_loss: 0.3296 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0745 - val_dist_relevant_mse: 3.0030 - val_dist_dist_iou_metric: 0.6706
# Epoch 41/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0675 - prob_loss: 0.0022 - dist_loss: 0.3264 - prob_kld: 0.0012 - dist_relevant_mae: 0.9524 - dist_relevant_mse: 1.7901 - dist_dist_iou_metric: 0.6738 - val_loss: 0.0679 - val_prob_loss: 0.0023 - val_dist_loss: 0.3281 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0736 - val_dist_relevant_mse: 2.7897 - val_dist_dist_iou_metric: 0.6722
# Epoch 42/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0652 - prob_loss: 0.0019 - dist_loss: 0.3165 - prob_kld: 8.9890e-04 - dist_relevant_mae: 0.9146 - dist_relevant_mse: 1.5864 - dist_dist_iou_metric: 0.6837 - val_loss: 0.0668 - val_prob_loss: 0.0022 - val_dist_loss: 0.3228 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0617 - val_dist_relevant_mse: 2.7741 - val_dist_dist_iou_metric: 0.6774
# Epoch 43/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0660 - prob_loss: 0.0024 - dist_loss: 0.3179 - prob_kld: 0.0012 - dist_relevant_mae: 0.9286 - dist_relevant_mse: 1.8957 - dist_dist_iou_metric: 0.6823 - val_loss: 0.0695 - val_prob_loss: 0.0022 - val_dist_loss: 0.3361 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1230 - val_dist_relevant_mse: 2.8903 - val_dist_dist_iou_metric: 0.6641
# Epoch 44/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0708 - prob_loss: 0.0025 - dist_loss: 0.3419 - prob_kld: 0.0016 - dist_relevant_mae: 0.9802 - dist_relevant_mse: 2.0974 - dist_dist_iou_metric: 0.6584 - val_loss: 0.0680 - val_prob_loss: 0.0023 - val_dist_loss: 0.3287 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0848 - val_dist_relevant_mse: 2.9709 - val_dist_dist_iou_metric: 0.6715
# Epoch 45/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0628 - prob_loss: 0.0021 - dist_loss: 0.3034 - prob_kld: 0.0010 - dist_relevant_mae: 0.9088 - dist_relevant_mse: 1.7321 - dist_dist_iou_metric: 0.6968 - val_loss: 0.0729 - val_prob_loss: 0.0022 - val_dist_loss: 0.3534 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.2085 - val_dist_relevant_mse: 3.1530 - val_dist_dist_iou_metric: 0.6468
# Epoch 46/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0691 - prob_loss: 0.0020 - dist_loss: 0.3354 - prob_kld: 0.0010 - dist_relevant_mae: 0.9988 - dist_relevant_mse: 1.8184 - dist_dist_iou_metric: 0.6649 - val_loss: 0.0663 - val_prob_loss: 0.0022 - val_dist_loss: 0.3206 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0452 - val_dist_relevant_mse: 2.8494 - val_dist_dist_iou_metric: 0.6796
# Epoch 47/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0670 - prob_loss: 0.0021 - dist_loss: 0.3245 - prob_kld: 0.0011 - dist_relevant_mae: 0.9743 - dist_relevant_mse: 1.9620 - dist_dist_iou_metric: 0.6757 - val_loss: 0.0668 - val_prob_loss: 0.0022 - val_dist_loss: 0.3230 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0608 - val_dist_relevant_mse: 2.7571 - val_dist_dist_iou_metric: 0.6773
# Epoch 48/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0634 - prob_loss: 0.0018 - dist_loss: 0.3079 - prob_kld: 9.1002e-04 - dist_relevant_mae: 0.8647 - dist_relevant_mse: 1.5160 - dist_dist_iou_metric: 0.6923 - val_loss: 0.0715 - val_prob_loss: 0.0022 - val_dist_loss: 0.3466 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1005 - val_dist_relevant_mse: 3.1778 - val_dist_dist_iou_metric: 0.6536
# Epoch 49/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0661 - prob_loss: 0.0021 - dist_loss: 0.3203 - prob_kld: 0.0010 - dist_relevant_mae: 0.9239 - dist_relevant_mse: 1.6754 - dist_dist_iou_metric: 0.6800 - val_loss: 0.0678 - val_prob_loss: 0.0023 - val_dist_loss: 0.3273 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0511 - val_dist_relevant_mse: 2.8466 - val_dist_dist_iou_metric: 0.6729
# Epoch 50/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0655 - prob_loss: 0.0020 - dist_loss: 0.3178 - prob_kld: 9.8065e-04 - dist_relevant_mae: 0.9265 - dist_relevant_mse: 1.7501 - dist_dist_iou_metric: 0.6824 - val_loss: 0.0670 - val_prob_loss: 0.0023 - val_dist_loss: 0.3233 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0469 - val_dist_relevant_mse: 2.8770 - val_dist_dist_iou_metric: 0.6769
# Epoch 51/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0641 - prob_loss: 0.0019 - dist_loss: 0.3109 - prob_kld: 9.7622e-04 - dist_relevant_mae: 0.8799 - dist_relevant_mse: 1.5219 - dist_dist_iou_metric: 0.6894 - val_loss: 0.0729 - val_prob_loss: 0.0022 - val_dist_loss: 0.3537 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1146 - val_dist_relevant_mse: 3.2060 - val_dist_dist_iou_metric: 0.6465
# Epoch 52/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0698 - prob_loss: 0.0018 - dist_loss: 0.3401 - prob_kld: 9.4041e-04 - dist_relevant_mae: 0.9265 - dist_relevant_mse: 1.7518 - dist_dist_iou_metric: 0.6601 - val_loss: 0.0697 - val_prob_loss: 0.0022 - val_dist_loss: 0.3377 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0747 - val_dist_relevant_mse: 3.0859 - val_dist_dist_iou_metric: 0.6625
# Epoch 53/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0664 - prob_loss: 0.0017 - dist_loss: 0.3234 - prob_kld: 8.4168e-04 - dist_relevant_mae: 0.8872 - dist_relevant_mse: 1.5585 - dist_dist_iou_metric: 0.6768 - val_loss: 0.0680 - val_prob_loss: 0.0022 - val_dist_loss: 0.3285 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0524 - val_dist_relevant_mse: 2.8083 - val_dist_dist_iou_metric: 0.6717
# Epoch 54/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0640 - prob_loss: 0.0021 - dist_loss: 0.3094 - prob_kld: 0.0011 - dist_relevant_mae: 0.9082 - dist_relevant_mse: 1.6829 - dist_dist_iou_metric: 0.6908 - val_loss: 0.0716 - val_prob_loss: 0.0022 - val_dist_loss: 0.3472 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0921 - val_dist_relevant_mse: 3.1033 - val_dist_dist_iou_metric: 0.6530
# Epoch 55/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0672 - prob_loss: 0.0021 - dist_loss: 0.3252 - prob_kld: 0.0011 - dist_relevant_mae: 0.9812 - dist_relevant_mse: 2.1544 - dist_dist_iou_metric: 0.6637 - val_loss: 0.0657 - val_prob_loss: 0.0022 - val_dist_loss: 0.3173 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0400 - val_dist_relevant_mse: 2.7008 - val_dist_dist_iou_metric: 0.6830
# Epoch 56/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0639 - prob_loss: 0.0020 - dist_loss: 0.3097 - prob_kld: 9.6773e-04 - dist_relevant_mae: 0.9023 - dist_relevant_mse: 1.7633 - dist_dist_iou_metric: 0.6860 - val_loss: 0.0707 - val_prob_loss: 0.0022 - val_dist_loss: 0.3424 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1491 - val_dist_relevant_mse: 2.8941 - val_dist_dist_iou_metric: 0.6579
# Epoch 57/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0644 - prob_loss: 0.0021 - dist_loss: 0.3113 - prob_kld: 9.8647e-04 - dist_relevant_mae: 0.8930 - dist_relevant_mse: 1.5923 - dist_dist_iou_metric: 0.6889 - val_loss: 0.0663 - val_prob_loss: 0.0022 - val_dist_loss: 0.3206 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0452 - val_dist_relevant_mse: 2.7724 - val_dist_dist_iou_metric: 0.6797
# Epoch 58/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0617 - prob_loss: 0.0018 - dist_loss: 0.2994 - prob_kld: 8.2524e-04 - dist_relevant_mae: 0.8654 - dist_relevant_mse: 1.4538 - dist_dist_iou_metric: 0.7008 - val_loss: 0.0662 - val_prob_loss: 0.0022 - val_dist_loss: 0.3203 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0495 - val_dist_relevant_mse: 2.7181 - val_dist_dist_iou_metric: 0.6800
# Epoch 59/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0656 - prob_loss: 0.0019 - dist_loss: 0.3186 - prob_kld: 9.9436e-04 - dist_relevant_mae: 0.9073 - dist_relevant_mse: 1.6702 - dist_dist_iou_metric: 0.6816 - val_loss: 0.0673 - val_prob_loss: 0.0022 - val_dist_loss: 0.3257 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0799 - val_dist_relevant_mse: 2.8135 - val_dist_dist_iou_metric: 0.6745
# Epoch 60/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0664 - prob_loss: 0.0020 - dist_loss: 0.3221 - prob_kld: 0.0011 - dist_relevant_mae: 0.9433 - dist_relevant_mse: 1.8446 - dist_dist_iou_metric: 0.6781 - val_loss: 0.0669 - val_prob_loss: 0.0022 - val_dist_loss: 0.3236 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0438 - val_dist_relevant_mse: 2.8622 - val_dist_dist_iou_metric: 0.6766
# Epoch 61/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0641 - prob_loss: 0.0018 - dist_loss: 0.3114 - prob_kld: 8.8729e-04 - dist_relevant_mae: 0.8642 - dist_relevant_mse: 1.4975 - dist_dist_iou_metric: 0.6888 - val_loss: 0.0670 - val_prob_loss: 0.0022 - val_dist_loss: 0.3240 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0387 - val_dist_relevant_mse: 2.8689 - val_dist_dist_iou_metric: 0.6762
# Epoch 62/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0602 - prob_loss: 0.0016 - dist_loss: 0.2930 - prob_kld: 7.5522e-04 - dist_relevant_mae: 0.8325 - dist_relevant_mse: 1.3711 - dist_dist_iou_metric: 0.7072 - val_loss: 0.0665 - val_prob_loss: 0.0022 - val_dist_loss: 0.3216 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0611 - val_dist_relevant_mse: 2.6905 - val_dist_dist_iou_metric: 0.6787
# Epoch 63/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0643 - prob_loss: 0.0023 - dist_loss: 0.3099 - prob_kld: 0.0013 - dist_relevant_mae: 0.8900 - dist_relevant_mse: 1.6576 - dist_dist_iou_metric: 0.6903 - val_loss: 0.0670 - val_prob_loss: 0.0022 - val_dist_loss: 0.3241 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0806 - val_dist_relevant_mse: 2.7398 - val_dist_dist_iou_metric: 0.6761
# Epoch 64/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0650 - prob_loss: 0.0019 - dist_loss: 0.3151 - prob_kld: 9.4405e-04 - dist_relevant_mae: 0.9167 - dist_relevant_mse: 1.7147 - dist_dist_iou_metric: 0.6851 - val_loss: 0.0668 - val_prob_loss: 0.0022 - val_dist_loss: 0.3231 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0462 - val_dist_relevant_mse: 2.9243 - val_dist_dist_iou_metric: 0.6771
# Epoch 65/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0623 - prob_loss: 0.0018 - dist_loss: 0.3027 - prob_kld: 8.3294e-04 - dist_relevant_mae: 0.8739 - dist_relevant_mse: 1.7057 - dist_dist_iou_metric: 0.6975 - val_loss: 0.0671 - val_prob_loss: 0.0022 - val_dist_loss: 0.3248 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0671 - val_dist_relevant_mse: 2.8595 - val_dist_dist_iou_metric: 0.6754
# Epoch 66/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0635 - prob_loss: 0.0018 - dist_loss: 0.3082 - prob_kld: 8.5091e-04 - dist_relevant_mae: 0.8848 - dist_relevant_mse: 1.6180 - dist_dist_iou_metric: 0.6889 - val_loss: 0.0667 - val_prob_loss: 0.0021 - val_dist_loss: 0.3228 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0300 - val_dist_relevant_mse: 2.8605 - val_dist_dist_iou_metric: 0.6774
# Epoch 67/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0667 - prob_loss: 0.0023 - dist_loss: 0.3218 - prob_kld: 0.0012 - dist_relevant_mae: 0.9196 - dist_relevant_mse: 1.6815 - dist_dist_iou_metric: 0.6784 - val_loss: 0.0653 - val_prob_loss: 0.0022 - val_dist_loss: 0.3152 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0351 - val_dist_relevant_mse: 2.6134 - val_dist_dist_iou_metric: 0.6851
# Epoch 68/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0620 - prob_loss: 0.0021 - dist_loss: 0.2997 - prob_kld: 0.0010 - dist_relevant_mae: 0.8630 - dist_relevant_mse: 1.4404 - dist_dist_iou_metric: 0.6977 - val_loss: 0.0695 - val_prob_loss: 0.0021 - val_dist_loss: 0.3368 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0669 - val_dist_relevant_mse: 3.0666 - val_dist_dist_iou_metric: 0.6634
# Epoch 69/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0650 - prob_loss: 0.0020 - dist_loss: 0.3148 - prob_kld: 0.0010 - dist_relevant_mae: 0.9079 - dist_relevant_mse: 1.6961 - dist_dist_iou_metric: 0.6854 - val_loss: 0.0758 - val_prob_loss: 0.0022 - val_dist_loss: 0.3679 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1262 - val_dist_relevant_mse: 3.2290 - val_dist_dist_iou_metric: 0.6323
# Epoch 70/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0677 - prob_loss: 0.0019 - dist_loss: 0.3288 - prob_kld: 8.8609e-04 - dist_relevant_mae: 0.9361 - dist_relevant_mse: 1.7831 - dist_dist_iou_metric: 0.6714 - val_loss: 0.0693 - val_prob_loss: 0.0022 - val_dist_loss: 0.3354 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0860 - val_dist_relevant_mse: 3.0874 - val_dist_dist_iou_metric: 0.6649
# Epoch 71/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0663 - prob_loss: 0.0022 - dist_loss: 0.3204 - prob_kld: 0.0012 - dist_relevant_mae: 0.9418 - dist_relevant_mse: 1.8692 - dist_dist_iou_metric: 0.6798 - val_loss: 0.0658 - val_prob_loss: 0.0021 - val_dist_loss: 0.3182 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0437 - val_dist_relevant_mse: 2.7435 - val_dist_dist_iou_metric: 0.6820
# Epoch 72/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0635 - prob_loss: 0.0017 - dist_loss: 0.3088 - prob_kld: 8.4943e-04 - dist_relevant_mae: 0.8708 - dist_relevant_mse: 1.5170 - dist_dist_iou_metric: 0.6913 - val_loss: 0.0693 - val_prob_loss: 0.0024 - val_dist_loss: 0.3344 - val_prob_kld: 0.0014 - val_dist_relevant_mae: 1.1066 - val_dist_relevant_mse: 2.9211 - val_dist_dist_iou_metric: 0.6658
# Epoch 73/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0672 - prob_loss: 0.0020 - dist_loss: 0.3258 - prob_kld: 0.0010 - dist_relevant_mae: 0.9684 - dist_relevant_mse: 2.0066 - dist_dist_iou_metric: 0.6744 - val_loss: 0.0682 - val_prob_loss: 0.0022 - val_dist_loss: 0.3304 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1025 - val_dist_relevant_mse: 2.9342 - val_dist_dist_iou_metric: 0.6698
# Epoch 74/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0632 - prob_loss: 0.0019 - dist_loss: 0.3065 - prob_kld: 9.9510e-04 - dist_relevant_mae: 0.8628 - dist_relevant_mse: 1.5012 - dist_dist_iou_metric: 0.6937 - val_loss: 0.0690 - val_prob_loss: 0.0022 - val_dist_loss: 0.3343 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.1252 - val_dist_relevant_mse: 2.8607 - val_dist_dist_iou_metric: 0.6659
# Epoch 75/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0644 - prob_loss: 0.0020 - dist_loss: 0.3118 - prob_kld: 0.0010 - dist_relevant_mae: 0.8871 - dist_relevant_mse: 1.6549 - dist_dist_iou_metric: 0.6884 - val_loss: 0.0644 - val_prob_loss: 0.0021 - val_dist_loss: 0.3116 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0181 - val_dist_relevant_mse: 2.6757 - val_dist_dist_iou_metric: 0.6886
# Epoch 76/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0613 - prob_loss: 0.0018 - dist_loss: 0.2975 - prob_kld: 8.6682e-04 - dist_relevant_mae: 0.8466 - dist_relevant_mse: 1.3833 - dist_dist_iou_metric: 0.7026 - val_loss: 0.0705 - val_prob_loss: 0.0021 - val_dist_loss: 0.3423 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0568 - val_dist_relevant_mse: 2.9523 - val_dist_dist_iou_metric: 0.6579
# Epoch 77/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0653 - prob_loss: 0.0021 - dist_loss: 0.3161 - prob_kld: 0.0010 - dist_relevant_mae: 0.8951 - dist_relevant_mse: 1.8493 - dist_dist_iou_metric: 0.6841 - val_loss: 0.0653 - val_prob_loss: 0.0022 - val_dist_loss: 0.3153 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0195 - val_dist_relevant_mse: 2.7691 - val_dist_dist_iou_metric: 0.6849
# Epoch 78/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0656 - prob_loss: 0.0020 - dist_loss: 0.3179 - prob_kld: 9.1970e-04 - dist_relevant_mae: 0.9712 - dist_relevant_mse: 2.0783 - dist_dist_iou_metric: 0.6823 - val_loss: 0.0652 - val_prob_loss: 0.0021 - val_dist_loss: 0.3152 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0016 - val_dist_relevant_mse: 2.6821 - val_dist_dist_iou_metric: 0.6849
# Epoch 79/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0615 - prob_loss: 0.0019 - dist_loss: 0.2980 - prob_kld: 9.1816e-04 - dist_relevant_mae: 0.8160 - dist_relevant_mse: 1.3630 - dist_dist_iou_metric: 0.7021 - val_loss: 0.0655 - val_prob_loss: 0.0021 - val_dist_loss: 0.3167 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0385 - val_dist_relevant_mse: 2.7911 - val_dist_dist_iou_metric: 0.6835
# Epoch 80/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0629 - prob_loss: 0.0017 - dist_loss: 0.3057 - prob_kld: 8.0086e-04 - dist_relevant_mae: 0.8643 - dist_relevant_mse: 1.4347 - dist_dist_iou_metric: 0.6945 - val_loss: 0.0657 - val_prob_loss: 0.0022 - val_dist_loss: 0.3177 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0501 - val_dist_relevant_mse: 2.7975 - val_dist_dist_iou_metric: 0.6825
# Epoch 81/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0630 - prob_loss: 0.0019 - dist_loss: 0.3055 - prob_kld: 9.2164e-04 - dist_relevant_mae: 0.9061 - dist_relevant_mse: 1.7863 - dist_dist_iou_metric: 0.6854 - val_loss: 0.0731 - val_prob_loss: 0.0021 - val_dist_loss: 0.3548 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.1048 - val_dist_relevant_mse: 3.1065 - val_dist_dist_iou_metric: 0.6454
# Epoch 82/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0662 - prob_loss: 0.0022 - dist_loss: 0.3201 - prob_kld: 0.0011 - dist_relevant_mae: 0.9107 - dist_relevant_mse: 1.6249 - dist_dist_iou_metric: 0.6713 - val_loss: 0.0650 - val_prob_loss: 0.0022 - val_dist_loss: 0.3142 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0163 - val_dist_relevant_mse: 2.6789 - val_dist_dist_iou_metric: 0.6860
# Epoch 83/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0634 - prob_loss: 0.0017 - dist_loss: 0.3082 - prob_kld: 8.7621e-04 - dist_relevant_mae: 0.8704 - dist_relevant_mse: 1.5218 - dist_dist_iou_metric: 0.6906 - val_loss: 0.0670 - val_prob_loss: 0.0021 - val_dist_loss: 0.3246 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0196 - val_dist_relevant_mse: 2.7894 - val_dist_dist_iou_metric: 0.6756
# Epoch 84/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0670 - prob_loss: 0.0023 - dist_loss: 0.3237 - prob_kld: 0.0014 - dist_relevant_mae: 0.9010 - dist_relevant_mse: 1.7246 - dist_dist_iou_metric: 0.6765 - val_loss: 0.0656 - val_prob_loss: 0.0022 - val_dist_loss: 0.3170 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0530 - val_dist_relevant_mse: 2.6577 - val_dist_dist_iou_metric: 0.6832
# Epoch 85/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0597 - prob_loss: 0.0019 - dist_loss: 0.2889 - prob_kld: 8.5171e-04 - dist_relevant_mae: 0.8358 - dist_relevant_mse: 1.4070 - dist_dist_iou_metric: 0.6990 - val_loss: 0.0681 - val_prob_loss: 0.0022 - val_dist_loss: 0.3294 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0989 - val_dist_relevant_mse: 2.7980 - val_dist_dist_iou_metric: 0.6708
# Epoch 86/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0614 - prob_loss: 0.0019 - dist_loss: 0.2973 - prob_kld: 8.9957e-04 - dist_relevant_mae: 0.8493 - dist_relevant_mse: 1.5150 - dist_dist_iou_metric: 0.7028 - val_loss: 0.0657 - val_prob_loss: 0.0021 - val_dist_loss: 0.3180 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0517 - val_dist_relevant_mse: 2.6617 - val_dist_dist_iou_metric: 0.6823
# Epoch 87/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0613 - prob_loss: 0.0018 - dist_loss: 0.2976 - prob_kld: 8.5089e-04 - dist_relevant_mae: 0.8301 - dist_relevant_mse: 1.4433 - dist_dist_iou_metric: 0.7026 - val_loss: 0.0658 - val_prob_loss: 0.0023 - val_dist_loss: 0.3177 - val_prob_kld: 0.0013 - val_dist_relevant_mae: 1.0380 - val_dist_relevant_mse: 2.8391 - val_dist_dist_iou_metric: 0.6825
# Epoch 88/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0645 - prob_loss: 0.0018 - dist_loss: 0.3134 - prob_kld: 8.8299e-04 - dist_relevant_mae: 0.8911 - dist_relevant_mse: 1.6320 - dist_dist_iou_metric: 0.6868 - val_loss: 0.0647 - val_prob_loss: 0.0021 - val_dist_loss: 0.3131 - val_prob_kld: 0.0011 - val_dist_relevant_mae: 1.0000 - val_dist_relevant_mse: 2.6354 - val_dist_dist_iou_metric: 0.6870
# Epoch 89/350
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0647 - prob_loss: 0.0017 - dist_loss: 0.3146 - prob_kld: 8.2181e-04 - dist_relevant_mae: 0.9322 - dist_relevant_mse: 1.9690 - dist_dist_iou_metric: 0.6855 - val_loss: 0.0652 - val_prob_loss: 0.0022 - val_dist_loss: 0.3152 - val_prob_kld: 0.0012 - val_dist_relevant_mae: 1.0201 - val_dist_relevant_mse: 2.8806 - val_dist_dist_iou_metric: 0.6849
# Epoch 90/350
# ...
# Epoch 315/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0516 - prob_loss: 0.0016 - dist_loss: 0.2500 - prob_kld: 6.6748e-04 - dist_relevant_mae: 0.7032 - dist_relevant_mse: 1.1210 - dist_dist_iou_metric: 0.7378 - val_loss: 0.0614 - val_prob_loss: 0.0020 - val_dist_loss: 0.2971 - val_prob_kld: 9.6846e-04 - val_dist_relevant_mae: 0.9596 - val_dist_relevant_mse: 2.4549 - val_dist_dist_iou_metric: 0.7029
# Epoch 316/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0530 - prob_loss: 0.0017 - dist_loss: 0.2567 - prob_kld: 7.4689e-04 - dist_relevant_mae: 0.6808 - dist_relevant_mse: 1.0145 - dist_dist_iou_metric: 0.7434 - val_loss: 0.0608 - val_prob_loss: 0.0020 - val_dist_loss: 0.2941 - val_prob_kld: 9.6296e-04 - val_dist_relevant_mae: 0.9479 - val_dist_relevant_mse: 2.3874 - val_dist_dist_iou_metric: 0.7059
# Epoch 317/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0486 - prob_loss: 0.0016 - dist_loss: 0.2348 - prob_kld: 6.4136e-04 - dist_relevant_mae: 0.6643 - dist_relevant_mse: 1.0142 - dist_dist_iou_metric: 0.7444 - val_loss: 0.0614 - val_prob_loss: 0.0020 - val_dist_loss: 0.2969 - val_prob_kld: 9.8065e-04 - val_dist_relevant_mae: 0.9569 - val_dist_relevant_mse: 2.4596 - val_dist_dist_iou_metric: 0.7031
# Epoch 318/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0532 - prob_loss: 0.0019 - dist_loss: 0.2566 - prob_kld: 8.6947e-04 - dist_relevant_mae: 0.7254 - dist_relevant_mse: 1.2498 - dist_dist_iou_metric: 0.7324 - val_loss: 0.0615 - val_prob_loss: 0.0020 - val_dist_loss: 0.2974 - val_prob_kld: 9.8276e-04 - val_dist_relevant_mae: 0.9629 - val_dist_relevant_mse: 2.3967 - val_dist_dist_iou_metric: 0.7026
# Epoch 319/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0489 - prob_loss: 0.0016 - dist_loss: 0.2367 - prob_kld: 6.8342e-04 - dist_relevant_mae: 0.6595 - dist_relevant_mse: 1.0193 - dist_dist_iou_metric: 0.7218 - val_loss: 0.0621 - val_prob_loss: 0.0020 - val_dist_loss: 0.3007 - val_prob_kld: 9.7050e-04 - val_dist_relevant_mae: 0.9583 - val_dist_relevant_mse: 2.4624 - val_dist_dist_iou_metric: 0.6993
# Epoch 320/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0513 - prob_loss: 0.0018 - dist_loss: 0.2476 - prob_kld: 7.5432e-04 - dist_relevant_mae: 0.6701 - dist_relevant_mse: 1.0177 - dist_dist_iou_metric: 0.7498 - val_loss: 0.0617 - val_prob_loss: 0.0020 - val_dist_loss: 0.2986 - val_prob_kld: 9.7555e-04 - val_dist_relevant_mae: 0.9658 - val_dist_relevant_mse: 2.3767 - val_dist_dist_iou_metric: 0.7014
# Epoch 321/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0514 - prob_loss: 0.0017 - dist_loss: 0.2482 - prob_kld: 7.2957e-04 - dist_relevant_mae: 0.7153 - dist_relevant_mse: 1.1805 - dist_dist_iou_metric: 0.7518 - val_loss: 0.0617 - val_prob_loss: 0.0020 - val_dist_loss: 0.2986 - val_prob_kld: 9.7905e-04 - val_dist_relevant_mae: 0.9580 - val_dist_relevant_mse: 2.4644 - val_dist_dist_iou_metric: 0.7014
# Epoch 322/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0544 - prob_loss: 0.0017 - dist_loss: 0.2635 - prob_kld: 7.5226e-04 - dist_relevant_mae: 0.7145 - dist_relevant_mse: 1.1443 - dist_dist_iou_metric: 0.7365 - val_loss: 0.0615 - val_prob_loss: 0.0020 - val_dist_loss: 0.2977 - val_prob_kld: 9.8140e-04 - val_dist_relevant_mae: 0.9583 - val_dist_relevant_mse: 2.4389 - val_dist_dist_iou_metric: 0.7023
# Epoch 323/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0521 - prob_loss: 0.0017 - dist_loss: 0.2520 - prob_kld: 7.1556e-04 - dist_relevant_mae: 0.7008 - dist_relevant_mse: 1.1423 - dist_dist_iou_metric: 0.7480 - val_loss: 0.0617 - val_prob_loss: 0.0020 - val_dist_loss: 0.2987 - val_prob_kld: 9.9640e-04 - val_dist_relevant_mae: 0.9647 - val_dist_relevant_mse: 2.4523 - val_dist_dist_iou_metric: 0.7013
# Epoch 324/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0515 - prob_loss: 0.0018 - dist_loss: 0.2487 - prob_kld: 7.8618e-04 - dist_relevant_mae: 0.6814 - dist_relevant_mse: 1.0027 - dist_dist_iou_metric: 0.7513 - val_loss: 0.0613 - val_prob_loss: 0.0020 - val_dist_loss: 0.2965 - val_prob_kld: 9.8222e-04 - val_dist_relevant_mae: 0.9531 - val_dist_relevant_mse: 2.4067 - val_dist_dist_iou_metric: 0.7035
# Epoch 325/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0520 - prob_loss: 0.0020 - dist_loss: 0.2501 - prob_kld: 9.0792e-04 - dist_relevant_mae: 0.7403 - dist_relevant_mse: 1.3142 - dist_dist_iou_metric: 0.7500 - val_loss: 0.0617 - val_prob_loss: 0.0020 - val_dist_loss: 0.2986 - val_prob_kld: 9.8553e-04 - val_dist_relevant_mae: 0.9626 - val_dist_relevant_mse: 2.4155 - val_dist_dist_iou_metric: 0.7014
# Epoch 326/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0546 - prob_loss: 0.0016 - dist_loss: 0.2651 - prob_kld: 7.0783e-04 - dist_relevant_mae: 0.6988 - dist_relevant_mse: 1.0271 - dist_dist_iou_metric: 0.7349 - val_loss: 0.0620 - val_prob_loss: 0.0020 - val_dist_loss: 0.3001 - val_prob_kld: 9.9764e-04 - val_dist_relevant_mae: 0.9683 - val_dist_relevant_mse: 2.4636 - val_dist_dist_iou_metric: 0.6999
# Epoch 327/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0526 - prob_loss: 0.0016 - dist_loss: 0.2547 - prob_kld: 7.0200e-04 - dist_relevant_mae: 0.6900 - dist_relevant_mse: 1.0964 - dist_dist_iou_metric: 0.7452 - val_loss: 0.0612 - val_prob_loss: 0.0020 - val_dist_loss: 0.2962 - val_prob_kld: 9.6307e-04 - val_dist_relevant_mae: 0.9534 - val_dist_relevant_mse: 2.3835 - val_dist_dist_iou_metric: 0.7038
# Epoch 328/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0545 - prob_loss: 0.0020 - dist_loss: 0.2624 - prob_kld: 9.4777e-04 - dist_relevant_mae: 0.7175 - dist_relevant_mse: 1.1743 - dist_dist_iou_metric: 0.7376 - val_loss: 0.0613 - val_prob_loss: 0.0020 - val_dist_loss: 0.2967 - val_prob_kld: 9.7205e-04 - val_dist_relevant_mae: 0.9515 - val_dist_relevant_mse: 2.4233 - val_dist_dist_iou_metric: 0.7033
# Epoch 329/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0537 - prob_loss: 0.0016 - dist_loss: 0.2607 - prob_kld: 6.5392e-04 - dist_relevant_mae: 0.7183 - dist_relevant_mse: 1.0987 - dist_dist_iou_metric: 0.7393 - val_loss: 0.0618 - val_prob_loss: 0.0020 - val_dist_loss: 0.2993 - val_prob_kld: 9.7088e-04 - val_dist_relevant_mae: 0.9595 - val_dist_relevant_mse: 2.4723 - val_dist_dist_iou_metric: 0.7007
# Epoch 330/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0538 - prob_loss: 0.0016 - dist_loss: 0.2609 - prob_kld: 7.0891e-04 - dist_relevant_mae: 0.7096 - dist_relevant_mse: 1.1734 - dist_dist_iou_metric: 0.7391 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2979 - val_prob_kld: 9.9017e-04 - val_dist_relevant_mae: 0.9639 - val_dist_relevant_mse: 2.3764 - val_dist_dist_iou_metric: 0.7021
# Epoch 331/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0523 - prob_loss: 0.0018 - dist_loss: 0.2528 - prob_kld: 7.9698e-04 - dist_relevant_mae: 0.7172 - dist_relevant_mse: 1.1358 - dist_dist_iou_metric: 0.7472 - val_loss: 0.0620 - val_prob_loss: 0.0020 - val_dist_loss: 0.3003 - val_prob_kld: 9.5701e-04 - val_dist_relevant_mae: 0.9583 - val_dist_relevant_mse: 2.4730 - val_dist_dist_iou_metric: 0.6997
# Epoch 332/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0510 - prob_loss: 0.0016 - dist_loss: 0.2471 - prob_kld: 6.7704e-04 - dist_relevant_mae: 0.6684 - dist_relevant_mse: 0.9533 - dist_dist_iou_metric: 0.7529 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2980 - val_prob_kld: 9.7569e-04 - val_dist_relevant_mae: 0.9635 - val_dist_relevant_mse: 2.4500 - val_dist_dist_iou_metric: 0.7020
# Epoch 333/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0527 - prob_loss: 0.0017 - dist_loss: 0.2552 - prob_kld: 7.0364e-04 - dist_relevant_mae: 0.7125 - dist_relevant_mse: 1.1468 - dist_dist_iou_metric: 0.7448 - val_loss: 0.0615 - val_prob_loss: 0.0020 - val_dist_loss: 0.2975 - val_prob_kld: 9.6737e-04 - val_dist_relevant_mae: 0.9528 - val_dist_relevant_mse: 2.4280 - val_dist_dist_iou_metric: 0.7025
# Epoch 334/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0535 - prob_loss: 0.0018 - dist_loss: 0.2582 - prob_kld: 8.6989e-04 - dist_relevant_mae: 0.7162 - dist_relevant_mse: 1.1665 - dist_dist_iou_metric: 0.7418 - val_loss: 0.0614 - val_prob_loss: 0.0020 - val_dist_loss: 0.2974 - val_prob_kld: 9.6868e-04 - val_dist_relevant_mae: 0.9583 - val_dist_relevant_mse: 2.3808 - val_dist_dist_iou_metric: 0.7026
# Epoch 335/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0529 - prob_loss: 0.0019 - dist_loss: 0.2551 - prob_kld: 7.7992e-04 - dist_relevant_mae: 0.7071 - dist_relevant_mse: 1.0846 - dist_dist_iou_metric: 0.7449 - val_loss: 0.0613 - val_prob_loss: 0.0020 - val_dist_loss: 0.2965 - val_prob_kld: 9.7632e-04 - val_dist_relevant_mae: 0.9558 - val_dist_relevant_mse: 2.4171 - val_dist_dist_iou_metric: 0.7035
# Epoch 336/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0522 - prob_loss: 0.0016 - dist_loss: 0.2528 - prob_kld: 6.7533e-04 - dist_relevant_mae: 0.6854 - dist_relevant_mse: 1.0339 - dist_dist_iou_metric: 0.7472 - val_loss: 0.0612 - val_prob_loss: 0.0020 - val_dist_loss: 0.2961 - val_prob_kld: 9.5779e-04 - val_dist_relevant_mae: 0.9531 - val_dist_relevant_mse: 2.4092 - val_dist_dist_iou_metric: 0.7039
# Epoch 337/350
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0533 - prob_loss: 0.0023 - dist_loss: 0.2549 - prob_kld: 0.0012 - dist_relevant_mae: 0.7359 - dist_relevant_mse: 1.3318 - dist_dist_iou_metric: 0.7452 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2982 - val_prob_kld: 9.7462e-04 - val_dist_relevant_mae: 0.9583 - val_dist_relevant_mse: 2.4358 - val_dist_dist_iou_metric: 0.7018
# Epoch 338/350
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0524 - prob_loss: 0.0017 - dist_loss: 0.2538 - prob_kld: 7.7176e-04 - dist_relevant_mae: 0.6861 - dist_relevant_mse: 1.0607 - dist_dist_iou_metric: 0.7462 - val_loss: 0.0615 - val_prob_loss: 0.0020 - val_dist_loss: 0.2977 - val_prob_kld: 9.6367e-04 - val_dist_relevant_mae: 0.9550 - val_dist_relevant_mse: 2.3965 - val_dist_dist_iou_metric: 0.7023
# Epoch 339/350
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0513 - prob_loss: 0.0018 - dist_loss: 0.2475 - prob_kld: 7.8846e-04 - dist_relevant_mae: 0.6863 - dist_relevant_mse: 1.0022 - dist_dist_iou_metric: 0.7525 - val_loss: 0.0622 - val_prob_loss: 0.0020 - val_dist_loss: 0.3011 - val_prob_kld: 9.8934e-04 - val_dist_relevant_mae: 0.9702 - val_dist_relevant_mse: 2.4157 - val_dist_dist_iou_metric: 0.6989
# Epoch 340/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0549 - prob_loss: 0.0018 - dist_loss: 0.2655 - prob_kld: 8.6457e-04 - dist_relevant_mae: 0.7660 - dist_relevant_mse: 1.3553 - dist_dist_iou_metric: 0.7345 - val_loss: 0.0612 - val_prob_loss: 0.0020 - val_dist_loss: 0.2963 - val_prob_kld: 9.5462e-04 - val_dist_relevant_mae: 0.9501 - val_dist_relevant_mse: 2.3301 - val_dist_dist_iou_metric: 0.7037
# Epoch 341/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0530 - prob_loss: 0.0017 - dist_loss: 0.2567 - prob_kld: 7.3574e-04 - dist_relevant_mae: 0.6878 - dist_relevant_mse: 1.0549 - dist_dist_iou_metric: 0.7433 - val_loss: 0.0618 - val_prob_loss: 0.0020 - val_dist_loss: 0.2991 - val_prob_kld: 9.8545e-04 - val_dist_relevant_mae: 0.9609 - val_dist_relevant_mse: 2.3813 - val_dist_dist_iou_metric: 0.7009
# Epoch 342/350
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0500 - prob_loss: 0.0017 - dist_loss: 0.2418 - prob_kld: 6.6273e-04 - dist_relevant_mae: 0.6664 - dist_relevant_mse: 1.0065 - dist_dist_iou_metric: 0.7582 - val_loss: 0.0613 - val_prob_loss: 0.0020 - val_dist_loss: 0.2965 - val_prob_kld: 9.7383e-04 - val_dist_relevant_mae: 0.9581 - val_dist_relevant_mse: 2.4005 - val_dist_dist_iou_metric: 0.7035
# Epoch 343/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0510 - prob_loss: 0.0017 - dist_loss: 0.2466 - prob_kld: 7.0611e-04 - dist_relevant_mae: 0.6822 - dist_relevant_mse: 1.0960 - dist_dist_iou_metric: 0.7534 - val_loss: 0.0619 - val_prob_loss: 0.0020 - val_dist_loss: 0.2994 - val_prob_kld: 9.9023e-04 - val_dist_relevant_mae: 0.9637 - val_dist_relevant_mse: 2.4415 - val_dist_dist_iou_metric: 0.7006
# Epoch 344/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0505 - prob_loss: 0.0017 - dist_loss: 0.2441 - prob_kld: 7.1468e-04 - dist_relevant_mae: 0.6862 - dist_relevant_mse: 1.1475 - dist_dist_iou_metric: 0.7560 - val_loss: 0.0621 - val_prob_loss: 0.0020 - val_dist_loss: 0.3006 - val_prob_kld: 9.8775e-04 - val_dist_relevant_mae: 0.9663 - val_dist_relevant_mse: 2.4881 - val_dist_dist_iou_metric: 0.6994
# Epoch 345/350
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0529 - prob_loss: 0.0017 - dist_loss: 0.2563 - prob_kld: 7.3182e-04 - dist_relevant_mae: 0.7139 - dist_relevant_mse: 1.0592 - dist_dist_iou_metric: 0.7437 - val_loss: 0.0618 - val_prob_loss: 0.0020 - val_dist_loss: 0.2994 - val_prob_kld: 9.7356e-04 - val_dist_relevant_mae: 0.9674 - val_dist_relevant_mse: 2.3707 - val_dist_dist_iou_metric: 0.7006
# Epoch 346/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0514 - prob_loss: 0.0019 - dist_loss: 0.2474 - prob_kld: 8.4644e-04 - dist_relevant_mae: 0.6964 - dist_relevant_mse: 1.1391 - dist_dist_iou_metric: 0.7526 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2981 - val_prob_kld: 9.6900e-04 - val_dist_relevant_mae: 0.9586 - val_dist_relevant_mse: 2.4366 - val_dist_dist_iou_metric: 0.7019
#
# Epoch 00346: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# Epoch 347/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0500 - prob_loss: 0.0017 - dist_loss: 0.2415 - prob_kld: 6.8437e-04 - dist_relevant_mae: 0.6620 - dist_relevant_mse: 0.9943 - dist_dist_iou_metric: 0.7585 - val_loss: 0.0615 - val_prob_loss: 0.0020 - val_dist_loss: 0.2978 - val_prob_kld: 9.6434e-04 - val_dist_relevant_mae: 0.9565 - val_dist_relevant_mse: 2.4443 - val_dist_dist_iou_metric: 0.7022
# Epoch 348/350
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0529 - prob_loss: 0.0023 - dist_loss: 0.2530 - prob_kld: 0.0012 - dist_relevant_mae: 0.7228 - dist_relevant_mse: 1.2760 - dist_dist_iou_metric: 0.7470 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2982 - val_prob_kld: 9.6350e-04 - val_dist_relevant_mae: 0.9569 - val_dist_relevant_mse: 2.4058 - val_dist_dist_iou_metric: 0.7018
# Epoch 349/350
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0514 - prob_loss: 0.0016 - dist_loss: 0.2490 - prob_kld: 6.5733e-04 - dist_relevant_mae: 0.6553 - dist_relevant_mse: 0.9783 - dist_dist_iou_metric: 0.7510 - val_loss: 0.0616 - val_prob_loss: 0.0020 - val_dist_loss: 0.2981 - val_prob_kld: 9.6259e-04 - val_dist_relevant_mae: 0.9572 - val_dist_relevant_mse: 2.4125 - val_dist_dist_iou_metric: 0.7019
# Epoch 350/350
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0488 - prob_loss: 0.0019 - dist_loss: 0.2344 - prob_kld: 7.8917e-04 - dist_relevant_mae: 0.6490 - dist_relevant_mse: 0.8866 - dist_dist_iou_metric: 0.7645 - val_loss: 0.0618 - val_prob_loss: 0.0020 - val_dist_loss: 0.2993 - val_prob_kld: 9.6041e-04 - val_dist_relevant_mae: 0.9605 - val_dist_relevant_mse: 2.3823 - val_dist_dist_iou_metric: 0.7007
#
# Loading network weights from 'weights_best.h5'.
# NMS threshold = 0.3:  75%|███████▌  | 15/20 [00:09<00:03,  1.51it/s, 0.558 -> 0.618]
# NMS threshold = 0.4:  75%|███████▌  | 15/20 [00:08<00:02,  1.71it/s, 0.558 -> 0.617]
# NMS threshold = 0.5:  75%|███████▌  | 15/20 [00:08<00:02,  1.71it/s, 0.558 -> 0.618]
# Using optimized values: prob_thresh=0.559911, nms_thresh=0.3.
# Saving to 'thresholds.json'.
# Fold 5 completed.

# %%
model = StarDist2D(conf, name='yh2ax0', basedir=model_dir)
Y_pred = [model.predict_instances(x, show_tile_progress=False)[0] for x in X]

stat = matching_dataset(Y, Y_pred, thresh=0.1, show_progress=False)

data = {
    'model': ['testasm'],
    'tp': [stat.tp],
    'fp': [stat.fp],
    'fn': [stat.fn],
    'precision': [stat.precision],
    'recall': [stat.recall],
    'accuracy': [stat.accuracy]
}

df = pd.DataFrame(data)

df1 = pd.read_csv(results_file)

merged_df = pd.concat([df1, df], ignore_index=True)
merged_df = merged_df.sort_values(by='model', ascending=True)

merged_df.to_csv(results_file, index=False)
# Out:
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.623276, nms_thresh=0.5.
